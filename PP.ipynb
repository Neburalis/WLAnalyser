# %% [markdown]
# ### primary data processing
#
# - removing reactions
# - removing duplicates in text_entities and text blocks

# %%
import json
import loadotenv
import os
from openai import OpenAI
import re

loadotenv.load_env()

token = os.getenv("OPENAI_API_KEY")

# %%
client = OpenAI()

# %%
with open('TGDat/result.json', 'r', encoding='utf-8', errors='ignore') as f:
    data = json.load(f)

# %%
# format to human-readable
with open('TGDat/result_h.json', 'w', encoding='utf-8', errors='ignore') as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# %%
for i, message in enumerate(data['messages']):
    if message['type'] != 'message':
        print(i)
        print(json.dumps(message, ensure_ascii=False, indent=4))

# %%
to_delete = []

for i, message in enumerate(data['messages']):
    if message['type'] != 'message':
        to_delete.append(i)
    if 'reactions' in message:
        del data['messages'][i]['reactions']
    if 'text' in message:
        del data['messages'][i]['text']

for i in to_delete:
    del data['messages'][i]

# %%
# remove duplicates information
with open('TGDat/result_1.json', 'w', encoding='utf-8', errors='ignore') as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# %%
types = {'photo': {'count': 0, 'ids': []}, 'file': {'count': 0, 'ids': []}, 'video': {'count': 0, 'ids': []}}

for i, message in enumerate(data['messages']):
    if 'photo' in message:
        types['photo']['count'] += 1
        types['photo']['ids'].append(i)
    elif 'file' in message:
        types['file']['count'] += 1
        types['file']['ids'].append(i)
    elif 'video' in message:
        types['video']['count'] += 1
        types['video']['ids'].append(i)
    else:
        print(i)
        # print(json.dumps(message, ensure_ascii=False, indent=4))

# %%
print(data['messages'][types['photo']['ids'][30]])

# %% [markdown]
# ### Edit format from telegram to my own
#
# format:
# ```json
# {
#     "messages": [
#         {
#             "id": 1,
#             "content": {
#                 "plain_text": "some text",
#                 "md_text": "some *md* text",
#                 "image": {"file": "photos/photo_32", "width": 1280, "height": 720},
#                 "file": {"file_name": "SQR.pdf", "file": "files/file_1.pdf", mime_type: "application/pdf"},
#                 "video": {"file_name": "video.MP4", "file": "videos/video_1", "media_type": "video_file", "duration_seconds": 60, "width": 1280, "height": 720}
#             }
#         }
#     ]
# }
# ```

# %%
def convert_to_plain_text(text_entities):
    plain_text = ""
    for entity in text_entities:
        if entity['type'] == 'plain':
            plain_text += entity['text']
        else:
            plain_text += entity['text']
    return plain_text

# %%
def convert_to_md_text(text_entities):
    md_text = ""
    for entity in text_entities:
        if entity['type'] == 'plain':
            md_text += entity['text']
        elif entity['type'] == 'bold':
            md_text += f"**{entity['text']}**"
        elif entity['type'] == 'italic':
            md_text += f"*{entity['text']}*"
        elif entity['type'] == 'underline':
            md_text += f"__{entity['text']}__"
        elif entity['type'] == 'strikethrough':
            md_text += f"~~{entity['text']}~~"
        elif entity['type'] == 'blockquote':
            md_text += f"> {entity['text']}"
        elif entity['type'] == 'pre':
            md_text += f"```{entity['language']}\n{entity['text']}```"
        elif entity['type'] == 'spoiler':
            md_text += f"||{entity['text']}||"
        elif entity['type'] == 'text_link':
            md_text += f"[{entity['text']}]({entity['href']})"
        else:
            md_text += entity['text']
    return md_text

# %%
new_data = {"messages": []}
video_pattern = r'^(?!video/).*$'

for message in data['messages']:
    new_message = {"id": message['id'], "content": {
        'plain_text': convert_to_plain_text(message['text_entities']),
        'md_text': convert_to_md_text(message['text_entities'])}}

    if 'photo' in message:
        new_message['content']['image'] = {
            "image": {
                'file': message['photo'],
                'width': message['width'],
                'height': message['height']
            }}
    if 'file' in message:
        if re.match(video_pattern, message['mime_type']) is None:  # its video format
            video = {'file': message['file'],
                     'media_type': message['media_type'],
                     'duration_seconds': message['duration_seconds'],
                     'width': message['width'],
                     'height': message['height']}

            if 'file_name' in message:
                video['file_name'] = message['file_name']

            new_message['content']['video'] = {"video": video}
        else:  # not video format
            new_message['content']['file'] = {"file": {
                'file_name': message['file_name'],
                'file': message['file'],
                'mime_type': message['mime_type']
            }}
    new_data['messages'].append(new_message)

# %%
print(json.dumps(new_data, ensure_ascii=False, indent=1))
# Out:
# {
#  "messages": [
#   {
#    "id": 25,
#    "content": {
#     "plain_text": "📱 - Консольное приложение на Go для подготовки к собесу\n\nВключает в себя базовое тестирование по таким темам, как: \nканалы, структуры, мьютексы, WaitGroup. \n\nА также имеет задания, по типу найти ошибку в данном коде\n\n🙂Сделайте что-то подобное для других ЯП, в качестве пет-проекта\n\nПодписаться",
#     "md_text": "📱 **- Консольное **[приложение](https://github.com/rusinikita/trainer?tab=readme-ov-file#complex-questions)** на Go для подготовки к собесу**\n\nВключает в себя базовое тестирование по таким **темам**, как: \n```\nканалы, структуры, мьютексы, WaitGroup. \n\nА также имеет задания, по типу найти ошибку в данном коде```\n\n🙂Сделайте что-то подобное для других ЯП, в качестве пет-проекта\n\n> Подписаться",
#     "image": {
#      "image": {
#       "file": "photos/photo_2@19-05-2024_15-42-18.jpg",
#       "width": 1280,
#       "height": 646
#      }
#     }
#    }
#   },
#   {
#    "id": 26,
#    "content": {
#     "plain_text": "✔️ Нейронка Deepseek Coder \n\nМожет проверить ваш код на ошибки, также может с нуля написать, что душе угодно\n\nМне написала змейку на пайтон, правда медленно😊\n\nА вообще есть смысл в подобном, когда есть джпт?\n\nДа -🔥\nОнли чатик - 👍\n\n🟢Иногда натыкаюсь на простые и на первый взгляд полезные нейронки, но потом вспоминаю про чатик и мысль выложить отпадает)\n\n#Нейросети\n\nПодписаться",
#     "md_text": "✔️ **Нейронка** [Deepseek Coder](https://coder.deepseek.com/sign_in)** \n\nМожет проверить ваш код на ошибки, также может с нуля написать, что душе угодно**\n\n> Мне написала змейку на пайтон, правда медленно😊\n\n**А вообще есть смысл в подобном, когда есть джпт?\n\nДа** **-🔥\nОнли чатик - **👍**\n\n**🟢Иногда натыкаюсь на простые и на первый взгляд полезные нейронки, но потом вспоминаю про чатик и мысль выложить отпадает)\n\n#Нейросети\n**\n**> Подписаться",
#     "video": {
#      "video": {
#       "file": "video_files/IMG_4196.MP4",
#       "media_type": "video_file",
#       "duration_seconds": 14,
#       "width": 848,
#       "height": 704,
#       "file_name": "IMG_4196.MP4"
#      }
#     }
#    }
#   },
#   {
#    "id": 27,
#    "content": {
#     "plain_text": "🔍 Бороздя просторы Хабра, наткнулся на статейку про создание заготовки вредоносного ПО для MacOS.\n\nЕсли разбить по тезисами, то в ней содержится:\n- Знакомство с архитектурой macOS и с особенностями её безопасности\n- Погружение во внутреннее устройство и знакомство с ключевыми элементами: Mach API и ядро\n- Создавание заготовку зловредного ПО\n\n🔊На случай, если кому-то статья покажется интересной также, как и мне, тут оставлю ссылку на вторую часть.\n\nПодписаться",
#     "md_text": "🔍 Бороздя просторы Хабра, [наткнулся на статейку про](https://habr.com/ru/companies/bastion/articles/814185/) **создание заготовки вредоносного ПО для MacOS.\n\n**Если разбить по тезисами, то в ней содержится:**\n**```\n- Знакомство с архитектурой macOS и с особенностями её безопасности\n- Погружение во внутреннее устройство и знакомство с ключевыми элементами: Mach API и ядро\n- Создавание заготовку зловредного ПО```**\n\n**🔊**На случай, если кому-то статья покажется интересной также, как и мне, **[тут](https://habr.com/ru/companies/bastion/articles/814199/)[ ](https://habr.com/ru/companies/bastion/articles/814199/)[оставлю](https://habr.com/ru/companies/bastion/articles/814199/)** ссылку на вторую часть.\n\n**> Подписаться",
#     "image": {
#      "image": {
#       "file": "photos/photo_3@23-05-2024_18-21-49.jpg",
#       "width": 730,
#       "height": 361
#      }
#     }
#    }
#   },
#   {
#    "id": 29,
#    "content": {
#     "plain_text": "📱Выкачу еще один не плохой проект для изучения Git\n\nGit-it — десктопное приложение для изучения Git и для работы с GitHub.\n\nСодержит:\nЗадания с использованием настоящих Git и GitHub, а не эмуляторов. \n\n🔊Когда вы закончите все «испытания», у вас будут готовые репозитории на вашем аккаунте.\n\nПодписаться",
#     "md_text": "📱**Выкачу еще один не плохой проект для изучения Git**\n\n[Git-it](https://github.com/jlord/git-it-electron) —** десктопное приложение для изучения Git и для работы с GitHub.**\n\nСодержит:\n```\nЗадания с использованием настоящих Git и GitHub, а не эмуляторов. ```\n\n🔊Когда вы закончите все «испытания», у вас будут готовые репозитории на вашем аккаунте.\n\n> Подписаться",
#     "image": {
#      "image": {
#       "file": "photos/photo_4@26-05-2024_11-23-37.jpg",
#       "width": 1280,
#       "height": 1022
#      }
#     }
#    }
#   },
#   {
#    "id": 32,
#    "content": {
#     "plain_text": "В одном из айтишных чатов жалоба превратилась в хит. Парень просто закинул текст в Suno, а на выходе получил этот шедевр.\n\n@xor_journal",
#     "md_text": "В одном из айтишных чатов жалоба превратилась в хит. Парень просто закинул текст в Suno, а на выходе получил этот шедевр.\n\n[@xor_journal](https://t.me/+RFSqZ8QljlUzYmUy)",
#     "video": {
#      "video": {
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "media_type": "video_file",
#       "duration_seconds": 53,
#       "width": 576,
#       "height": 1248,
#       "file_name": "IMG_1478.MP4"
#      }
#     }
#    }
#   },
#   {
#    "id": 33,
#    "content": {
#     "plain_text": "Признавайтесь, у кого такие?",
#     "md_text": "Признавайтесь, у кого такие?",
#     "image": {
#      "image": {
#       "file": "photos/photo_5@06-06-2024_10-06-04.jpg",
#       "width": 961,
#       "height": 1280
#      }
#     }
#    }
#   },
#   {
#    "id": 37,
#    "content": {
#     "plain_text": "🖥Небольшая шпора по SQL\n\nСодержит подсказки по:\nВыборке данных. \nЗапросам к таблице. \nSET операциям. \nИ тд\n\nПолезно для тех, кто вначале пути:)\n\n#шпаргалки\n\nПодписаться",
#     "md_text": "🖥**Небольшая шпора по SQL**\n\nСодержит подсказки по:\n```\nВыборке данных. \nЗапросам к таблице. \nSET операциям. ```\nИ тд\n\n**Полезно для тех, кто вначале пути:)\n\n**#шпаргалки**\n\n**> Подписаться",
#     "file": {
#      "file": {
#       "file_name": "SQL.pdf",
#       "file": "files/SQL.pdf",
#       "mime_type": "application/pdf"
#      }
#     }
#    }
#   },
#   {
#    "id": 38,
#    "content": {
#     "plain_text": "🖥 Codon — высокопроизводительный компилятор Python, который компилирует код Python в нативный машинный код без каких-либо накладных расходов во время выполнения\n\n/bin/bash -c \"$(curl -fsSL https://exaloop.io/install.sh)\"\n# codon run my_code.py\n\nТипичное ускорение, достигаемое при помощи Codon, составляет порядка 10-100 или более раз, на одном потоке. \nПроизводительность Codon обычно находится на одном уровне с C/C++ (иногда даже превосходит его). \nТакже Codon поддерживает встроенную многопоточность, что может привести к многократному увеличению скорости.\n\nДля полноты картины стоит упомянуть, что Codon позволяет скомпилировать не любой код Python, некоторые функции просто невозможно скомпилировать таким образом.\n\n🖥 GitHub\n🟡 Доки\n\n@pythonl",
#     "md_text": "🖥 **Codon — высокопроизводительный компилятор Python, который компилирует код Python в нативный машинный код без каких-либо накладных расходов во время выполнения**\n\n```shell\n/bin/bash -c \"$(curl -fsSL https://exaloop.io/install.sh)\"\n# codon run my_code.py```\n\nТипичное ускорение, достигаемое при помощи Codon, составляет порядка 10-100 или более раз, на одном потоке. \nПроизводительность Codon обычно находится на одном уровне с C/C++ (иногда даже превосходит его). \nТакже Codon поддерживает встроенную многопоточность, что может привести к многократному увеличению скорости.\n\nДля полноты картины стоит упомянуть, что Codon позволяет скомпилировать не любой код Python, некоторые функции просто невозможно скомпилировать таким образом.\n\n🖥 [GitHub](https://github.com/exaloop/codon)\n🟡 [Доки](https://docs.exaloop.io/codon)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_6@08-07-2024_14-01-19.jpg",
#       "width": 1280,
#       "height": 686
#      }
#     }
#    }
#   },
#   {
#    "id": 39,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_7@08-07-2024_14-01-19.jpg",
#       "width": 1187,
#       "height": 989
#      }
#     }
#    }
#   },
#   {
#    "id": 40,
#    "content": {
#     "plain_text": "😎Нашел тут кое что, решил поделиться с вами\n\nИгры на Code Open\n1. Tower Blocks \n2. Бешеный бег доблестного кролика \n3. Platform game engine \n\nМало-ли, кто пилит сейчас браузерную игрулю и нуждается в готовых механиках)\n\nПодписаться",
#     "md_text": "😎**Нашел тут** **кое что, решил поделиться с вами\n\n**```\nИгры на Code Open```\n**1. **[Tower Blocks](https://codepen.io/ste-vg/pen/ppLQNW)** **\n**2. **[Бешеный бег доблестного кролика](https://codepen.io/Yakudoo/pen/YGxYej) \n**3. **[Platform game engine](https://codepen.io/dissimulate/pen/AGYEby) \n\nМало-ли, кто пилит сейчас браузерную игрулю и нуждается в готовых механиках)\n\n> Подписаться",
#     "image": {
#      "image": {
#       "file": "photos/photo_8@13-07-2024_18-34-11.jpg",
#       "width": 1280,
#       "height": 452
#      }
#     }
#    }
#   },
#   {
#    "id": 41,
#    "content": {
#     "plain_text": "🏢 Лучшее аниме о ностальгии | Видеоэссе\n\nВам очень понравилось эссе про Синкая, поэтому мы постарались поскорее сделать новую работу! В этот раз говорим о ностальгии. \n\nДействительно ли такая знакомая нам ностальгия — это хорошее чувство? Всегда ли она вызывает приятные эмоции? Или на самом деле привязанность к родным местам может помешать жить, вселить неуверенность и страх, встать на пути взросления? \n\nОбо всем этом в нашем новом эссе — о фильме «Дрейфующий дом». \n\nhttps://vk.com/video-211086713_456239145",
#     "md_text": "🏢 **Лучшее аниме о ностальгии | Видеоэссе**\n\nВам очень понравилось эссе про Синкая, поэтому мы постарались поскорее сделать новую работу! В этот раз говорим о ностальгии. \n\nДействительно ли такая знакомая нам ностальгия — это хорошее чувство? Всегда ли она вызывает приятные эмоции? Или на самом деле привязанность к родным местам может помешать жить, вселить неуверенность и страх, встать на пути взросления? \n\nОбо всем этом в нашем новом эссе — о фильме «Дрейфующий дом». \n\nhttps://vk.com/video-211086713_456239145",
#     "image": {
#      "image": {
#       "file": "photos/photo_9@25-07-2024_11-10-22.jpg",
#       "width": 1280,
#       "height": 720
#      }
#     }
#    }
#   },
#   {
#    "id": 42,
#    "content": {
#     "plain_text": "​Ловушка неинтересной работы\n\nСначала кажется, что как разработчик ты можешь выполнять любую работу, главное, чтобы платили побольше, но со временем это может привести к не самым лучшим результатам и закончиться дуркой.",
#     "md_text": "[​](https://hooks.pro/media/2024/07/17/bot5481537252/file-ZpeeZwFBlb.jpg)**Ловушка неинтересной работы**\n\nСначала кажется, что как разработчик ты можешь выполнять любую работу, главное, чтобы платили побольше, [но со временем это может привести к не самым лучшим результатам и закончиться дуркой](https://habr.com/ru/articles/828994/?utm_source=telegram_habr)."
#    }
#   },
#   {
#    "id": 43,
#    "content": {
#     "plain_text": "​Как компании удерживали, удерживают и будут удерживать сотрудников: блеск и нищета корпоративной культуры\n\nЕсли у вас есть время и желание заняться странной деятельностью, предлагаем вам развлечение под названием «кадровая археология». Суть проста — вы вводите в поиск запрос, вроде «вакансии в России в 1990-х» и по ним пытаетесь понять, как жили древние люди. А точнее, как мыслили HR-ы и их руководители, а также какой была ситуация на рынке труда.\n\nНаша задача на сегодня — проанализировать ряд найденных артефактов былой эпохи, дойти до наших дней и понять, как развивалась корпоративная культура, зачем она нужна и предположить, куда же она приведёт.",
#     "md_text": "[​](https://hooks.pro/media/2024/07/18/bot5481537252/file-ZpjkTw1G4n.jpg)**Как компании удерживали, удерживают и будут удерживать сотрудников: блеск и нищета корпоративной культуры**\n\nЕсли у вас есть время и желание заняться странной деятельностью, предлагаем вам развлечение под названием «кадровая археология». Суть проста — вы вводите в поиск запрос, вроде «вакансии в России в 1990-х» и по ним пытаетесь понять, как жили древние люди. А точнее, как мыслили HR-ы и их руководители, а также какой была ситуация на рынке труда.\n\nНаша задача на сегодня — проанализировать ряд найденных артефактов былой эпохи, дойти до наших дней и [понять, как развивалась корпоративная культура, зачем она нужна и предположить, куда же она приведёт](https://habr.com/ru/articles/829614/?utm_source=telegram_habr)."
#    }
#   },
#   {
#    "id": 44,
#    "content": {
#     "plain_text": "​«В среднем мы сетапим по три проекта в месяц. Их фронтовый стек основан на React, Styled Components или связке CSS modules с SCSS, MobX и Axios, а если это мини-приложение для ВКонтакте, то к списку добавляются еще VKUI и библиотека VK-Bridge для VK API.\n\nРаньше сборка такого стека занимала у нас довольно много времени, но со временем мы научились настраивать его в два счёта. Собственно, в статье пойдёт речь о том, как создать инструмент для быстрого сетапа проектов»\n\nИскусство сетапа: автоматизируем подготовку стека под новые проекты",
#     "md_text": "[​](https://hooks.pro/media/2024/07/18/bot5481537252/file-ZpjkvgxAL-.jpg)«**В среднем мы сетапим по три проекта в месяц.** Их фронтовый стек основан на React, Styled Components или связке CSS modules с SCSS, MobX и Axios, а если это мини-приложение для ВКонтакте, то к списку добавляются еще VKUI и библиотека VK-Bridge для VK API.\n\nРаньше сборка такого стека занимала у нас довольно много времени, но со временем мы научились настраивать его в два счёта. Собственно, в статье пойдёт речь о том, как создать инструмент для быстрого сетапа проектов»\n\n[Искусство сетапа: автоматизируем подготовку стека под новые проекты](https://habr.com/ru/companies/kts/articles/829460/?utm_source=telegram_habr)"
#    }
#   },
#   {
#    "id": 45,
#    "content": {
#     "plain_text": "​Эволюция систем пожарной сигнализации: от «камешков» до сигнализации в дата-центре\n\nС начала 2024 года в России произошло около 13 тысяч пожаров. Причиной становятся как неисправная электроника, так и детские шалости с огнём. На сегодня главным способом по предотвращению пожаров остается система сигнализации. Особенно когда эффективность тушения зависит от каждой секунды.\n\nОкунёмся в историю технологий пожарной безопасности и поговорим о том, откуда она появилась, как наказывали за поджоги и какие инструменты использовали для уведомления жителей и служб",
#     "md_text": "[​](https://hooks.pro/media/2024/07/18/bot5481537252/file-Zpjk_Quygc.jpg)**Эволюция систем пожарной сигнализации: от «камешков» до сигнализации в дата-центре**\n\nС начала 2024 года в России произошло около 13 тысяч пожаров. Причиной становятся как неисправная электроника, так и детские шалости с огнём. На сегодня главным способом по предотвращению пожаров остается система сигнализации. Особенно когда эффективность тушения зависит от каждой секунды.\n\n[Окунёмся в историю технологий пожарной безопасности и поговорим о том, откуда она появилась, как наказывали за поджоги и какие инструменты использовали для уведомления жителей и служб](https://habr.com/ru/companies/selectel/articles/827882/?utm_source=telegram_habr)"
#    }
#   },
#   {
#    "id": 46,
#    "content": {
#     "plain_text": "🌟 Подборка библиотек Python и разных компонентов для удобной работы в Jupyter Notebook\n\nДержите массу полезных ссылок на компонентны, расширения и библиотеки Python для более удобной работы в Jupyter Notebook. \nВ частности, для удобного построения графиков и визуализации, для совместной работы, для интеграции с другими приложениями\nЕсть даже jut для отображения Notebook'а в терминале\n\n🖥 GitHub\n\n@pythonl",
#     "md_text": "🌟 **Подборка библиотек Python и разных компонентов для удобной работы в Jupyter Notebook**\n\nДержите массу полезных ссылок на компонентны, расширения и библиотеки Python для более удобной работы в Jupyter Notebook. \nВ частности, для удобного построения графиков и визуализации, для совместной работы, для интеграции с другими приложениями\nЕсть даже [jut](https://github.com/kracekumar/jut) для отображения Notebook'а в терминале\n\n🖥 [GitHub](https://github.com/markusschanta/awesome-jupyter)\n\n[@pythonl](https://t.me/pythonl)",
#     "image": {
#      "image": {
#       "file": "photos/photo_10@02-08-2024_21-42-58.jpg",
#       "width": 1260,
#       "height": 964
#      }
#     }
#    }
#   },
#   {
#    "id": 47,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_11@02-08-2024_21-42-59.jpg",
#       "width": 1256,
#       "height": 717
#      }
#     }
#    }
#   },
#   {
#    "id": 48,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_12@02-08-2024_21-42-59.jpg",
#       "width": 1172,
#       "height": 997
#      }
#     }
#    }
#   },
#   {
#    "id": 49,
#    "content": {
#     "plain_text": "🖥 Robyn — асинхронный веб-фреймворк Python с Rust-рантаймом\n\n — pip install robyn\n\nRobyn — это очень быстрый веб-фреймворк, который объединяет асинхронные возможности Python и скорость Rust для создания высокопроизводительных веб-приложений. Быстрое построение проектов, удобное использование и надежная поддержка плагинов.\n\nRobyn отличается от остальных фреймворков.\nОбычно для запуска какого-то фреймворка нужен WSGI/ASGI-сервер: Gunicorn, uWSGI или Uvicorn, например. У Robin этого нет. Сразу идет рантайм, написанный на Rust, который реализует WSGI-сервер. С помощью PyO3 он интегрируется с Python и вызывает его функции. \nRobyn делает разбор и роутинг запроса на Rust, что ожидаемо работает быстро\n\n🖥 GitHub\n🟡 Доки\n\n@pythonl",
#     "md_text": "🖥 **Robyn — асинхронный веб-фреймворк Python с Rust-рантаймом**\n\n — pip install robyn\n\nRobyn — это очень быстрый веб-фреймворк, который объединяет асинхронные возможности Python и скорость Rust для создания высокопроизводительных веб-приложений. Быстрое построение проектов, удобное использование и надежная поддержка плагинов.\n\nRobyn отличается от остальных фреймворков.\nОбычно для запуска какого-то фреймворка нужен WSGI/ASGI-сервер: Gunicorn, uWSGI или Uvicorn, например. У Robin этого нет. Сразу идет рантайм, написанный на Rust, который реализует WSGI-сервер. С помощью PyO3 он интегрируется с Python и вызывает его функции. \nRobyn делает разбор и роутинг запроса на Rust, что ожидаемо работает быстро\n\n🖥 [GitHub](https://github.com/sparckles/Robyn)\n🟡 [Доки](https://robyn.tech/documentation)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_13@02-08-2024_21-46-50.jpg",
#       "width": 1280,
#       "height": 797
#      }
#     }
#    }
#   },
#   {
#    "id": 50,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_14@02-08-2024_21-46-50.jpg",
#       "width": 1205,
#       "height": 752
#      }
#     }
#    }
#   },
#   {
#    "id": 51,
#    "content": {
#     "plain_text": "🖥 Open3D — современная библиотека Python для 3D моделирования\n\n— pip install open3d\n\nOpen3D — это open-source библиотека, которая поддерживает быструю разработку ПО, работающего с 3D-данными. \nФронтенд Open3D предоставляет набор тщательно отобранных структур данных и алгоритмов на языках C++ и Python. Бэкэнд высоко оптимизирован и настроен на распараллеливание. \n\nОсновные возможности Open3D:\n — поддержка структур 3D-данных\n — алгоритмы обработки 3D-данных\n — реконструкция сцены\n — Выравнивание поверхностей\n — 3D-визуализация\n — рендеринг с учётом физики (PBR)\n — поддержка машинного 3D-обучения с помощью PyTorch и TensorFlow\n — ускорение GPU для основных 3D-операций\n\n🖥 GitHub\n🟡 Доки\n\n@pythonl",
#     "md_text": "🖥 **Open3D — современная библиотека Python для 3D моделирования**\n\n— pip install open3d\n\nOpen3D — это open-source библиотека, которая поддерживает быструю разработку ПО, работающего с 3D-данными. \nФронтенд Open3D предоставляет набор тщательно отобранных структур данных и алгоритмов на языках C++ и Python. Бэкэнд высоко оптимизирован и настроен на распараллеливание. \n\nОсновные возможности Open3D:\n — поддержка структур 3D-данных\n — алгоритмы обработки 3D-данных\n — реконструкция сцены\n — Выравнивание поверхностей\n — 3D-визуализация\n — рендеринг с учётом физики (PBR)\n — поддержка машинного 3D-обучения с помощью PyTorch и TensorFlow\n — ускорение GPU для основных 3D-операций\n\n🖥 [GitHub](https://github.com/isl-org/Open3D)\n🟡 [Доки](https://www.open3d.org/docs/release/)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_15@02-08-2024_21-47-29.jpg",
#       "width": 1280,
#       "height": 720
#      }
#     }
#    }
#   },
#   {
#    "id": 52,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_16@02-08-2024_21-47-29.jpg",
#       "width": 1280,
#       "height": 593
#      }
#     }
#    }
#   },
#   {
#    "id": 53,
#    "content": {
#     "plain_text": "🖥 Unfold — тема для кастомизации стандартной админ-панели Django\n\npip install django-unfold\npoetry add django-unfold\n\nUnfold — это тема для админки Django, которая позволяет добавить удобные для администратора функции. \n\n🖥 GitHub\n🟡 Посмотреть админку вживую\n\n@pythonl",
#     "md_text": "🖥 **Unfold — тема для кастомизации стандартной админ-панели Django**\n\n```shell\npip install django-unfold\npoetry add django-unfold```\n\nUnfold — это тема для админки Django, которая позволяет добавить удобные для администратора функции. \n\n🖥 [GitHub](https://github.com/unfoldadmin/django-unfold)\n🟡 [Посмотреть админку вживую](https://demo.unfoldadmin.com/)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_17@02-08-2024_21-53-58.jpg",
#       "width": 1280,
#       "height": 1166
#      }
#     }
#    }
#   },
#   {
#    "id": 54,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_18@02-08-2024_21-53-58.jpg",
#       "width": 1174,
#       "height": 1127
#      }
#     }
#    }
#   },
#   {
#    "id": 55,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_19@02-08-2024_21-53-58.jpg",
#       "width": 1280,
#       "height": 1063
#      }
#     }
#    }
#   },
#   {
#    "id": 56,
#    "content": {
#     "plain_text": "🖥 Logfire — observability-платформа, созданная командой Pydantic\n\n — pip install logfire\n\nLogfire — это платформа для мониторинга и observability.\nОсобенности Logfire: \n\n — предоставляет простой дашборд, который легко использовать\n\n — позволяет отображать объекты Python, профилировать код, визуализировать запросы к БД\n\n — Logfire отдаёт собранные данные по обычным SQL-запросам, не нужно учить новый диалект\n\nА также Logfire отлично интегрируется с OpenTelemetry и с Pydantic\n\n🖥 GitHub\n🟡 Доки\n\n@pythonl",
#     "md_text": "🖥 **Logfire — observability-платформа, созданная командой Pydantic**\n\n — pip install logfire\n\nLogfire — это платформа для мониторинга и observability.\nОсобенности Logfire: \n\n — предоставляет простой дашборд, который легко использовать\n\n — позволяет отображать объекты Python, профилировать код, визуализировать запросы к БД\n\n — Logfire отдаёт собранные данные по обычным SQL-запросам, не нужно учить новый диалект\n\nА также Logfire отлично интегрируется с OpenTelemetry и с Pydantic\n\n🖥 [GitHub](https://github.com/pydantic/logfire)\n🟡 [Доки](https://docs.pydantic.dev/logfire/)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_20@02-08-2024_21-55-49.jpg",
#       "width": 1280,
#       "height": 800
#      }
#     }
#    }
#   },
#   {
#    "id": 57,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_21@02-08-2024_21-55-49.jpg",
#       "width": 1280,
#       "height": 851
#      }
#     }
#    }
#   },
#   {
#    "id": 58,
#    "content": {
#     "plain_text": "🌟  Lets-Plot: мощная библиотека для визуализации данных на Python\n\n— pip install lets-plot\n\nLets-Plot — библиотека от JetBrains, созданная на основе принципов Grammar of Graphics, как и знаменитая ggplot2 для R.\n\nОсобенности и преимущества:\n\n- Мультиплатформенность: Lets-Plot работает как в блокнотах Python (Jupyter, Datalore, Kaggle и др.), так и в IDE PyCharm и IntelliJ IDEA.\n\n- Интерактивные возможности: Поддержка интерактивных карт с возможностью увеличения и перемещения, а также кастомизация подсказок и аннотаций.\n\n- Геопространственная визуализация: Простая интеграция с GeoDataFrame и мощный модуль геокодирования.\n\n- Экспорт графиков: Сохранение графиков в формате SVG, HTML, PNG и PDF с помощью функций ggsave(), to_svg(), to_html(), to_png() и to_pdf().\n\n- Поддержка режима без JavaScript и оффлайн-режима: Lets-Plot генерирует графики как простые SVG-изображения, что обеспечивает работу без Интернет-соединения.\n\n\n🖥 GitHub\n🟡 Доки\n\n@pythonl",
#     "md_text": "🌟  **Lets-Plot: мощная библиотека для визуализации данных на Python**\n\n— pip install lets-plot\n\nLets-Plot — библиотека от JetBrains, созданная на основе принципов Grammar of Graphics, как и знаменитая ggplot2 для R.\n\nОсобенности и преимущества:\n\n- Мультиплатформенность: Lets-Plot работает как в блокнотах Python (Jupyter, Datalore, Kaggle и др.), так и в IDE PyCharm и IntelliJ IDEA.\n\n- Интерактивные** **возможности: Поддержка интерактивных карт с возможностью увеличения и перемещения, а также кастомизация подсказок и аннотаций.\n\n- Геопространственная** **визуализация: Простая интеграция с GeoDataFrame и мощный модуль геокодирования.\n\n- Экспорт** **графиков: Сохранение графиков в формате SVG, HTML, PNG и PDF с помощью функций ggsave(), to_svg(), to_html(), to_png() и to_pdf().\n\n- Поддержка** **режима** **без** **JavaScript** **и** **оффлайн**-**режима: Lets-Plot генерирует графики как простые SVG-изображения, что обеспечивает работу без Интернет-соединения.\n\n\n🖥 [GitHub](https://github.com/JetBrains/lets-plot)\n🟡 [Доки](https://lets-plot.org/python/pages/api.html)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_22@02-08-2024_21-58-41.jpg",
#       "width": 767,
#       "height": 280
#      }
#     }
#    }
#   },
#   {
#    "id": 59,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_23@02-08-2024_21-58-41.jpg",
#       "width": 712,
#       "height": 301
#      }
#     }
#    }
#   },
#   {
#    "id": 60,
#    "content": {
#     "plain_text": "🖥  gTTS (Google Text-to-Speech) - Python библиотека и инструмент командной строки (CLI) для взаимодействия с API преобразования текста в речь Google Translate.\n\nВы можете использовать её для записи озвученного текста в файл формата MP3, объект-подобный файл (bytestring) для дальнейшей обработки аудио или непосредственно в стандартный вывод.\n\nОсобенности:\n- Настраиваемый токенизатор, который позволяет озвучивать текст любой длины, сохраняя правильную интонацию, сокращения, десятичные дроби и многое другое.\n- Возможность настройки предварительной обработки текста для корректировки произношения.\n\nУстановка:\npip install gTTS\nПример использования в командной строке:\ngtts-cli 'hello' --output hello.mp3\nИли в модуле Python:\nfrom gtts import gTTS\ntts = gTTS('hello')\ntts.save('hello.mp3')\n\n🖥 GitHub\n🟡Доки\n\n@pythonl",
#     "md_text": "🖥  **gTTS (Google Text-to-Speech)** - Python библиотека и инструмент командной строки (CLI) для взаимодействия с API преобразования текста в речь Google Translate.\n\nВы можете использовать её для записи озвученного текста в файл формата MP3, объект-подобный файл (bytestring) для дальнейшей обработки аудио или непосредственно в стандартный вывод.\n\nОсобенности:\n- Настраиваемый токенизатор, который позволяет озвучивать текст любой длины, сохраняя правильную интонацию, сокращения, десятичные дроби и многое другое.\n- Возможность настройки предварительной обработки текста для корректировки произношения.\n\nУстановка:\n```shell\npip install gTTS```\nПример использования в командной строке:\n```shell\ngtts-cli 'hello' --output hello.mp3```\nИли в модуле Python:\n```python\nfrom gtts import gTTS\ntts = gTTS('hello')\ntts.save('hello.mp3')```\n\n🖥 [GitHub](https://github.com/pndurette/gTTS)\n🟡[Доки](https://gtts.readthedocs.io/en/latest/index.html)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_24@03-08-2024_21-19-13.jpg",
#       "width": 540,
#       "height": 421
#      }
#     }
#    }
#   },
#   {
#    "id": 61,
#    "content": {
#     "plain_text": "🖥 Генерация CAPTCHA с помощью Python\n\nfrom captcha.image import ImageCaptcha\nfrom PIL import Image\ndef generate_captcha_text(length):\n  import string \n  import random \n  return ''.join(random.choices(string.ascii_letters + string.digits, k=length))\n\ndef generate_captcha(captcha_length=7, save_path='CAPTCHA.png'):\n  image = ImageCaptcha(width=500, height=100)\n  captcha_text = generate_captcha_text(captcha_length)\n  data = image.generate(captcha_text)\n  image.write(captcha_text, save_path)\n  return captcha_text\n\nif __name__ == '__main__':\n  captcha_text = generate_captcha()\n  print('CAPTCHA text:', captcha_text)\n\nImage.open('CAPTCHA.png')\n\nПри желании можно добавить дополнительных эффектов и т.д., чтобы даже ChatGPT не справился\n\n@pythonl",
#     "md_text": "🖥 **Генерация CAPTCHA с помощью Python**\n\n```python\nfrom captcha.image import ImageCaptcha\nfrom PIL import Image\ndef generate_captcha_text(length):\n  import string \n  import random \n  return ''.join(random.choices(string.ascii_letters + string.digits, k=length))\n\ndef generate_captcha(captcha_length=7, save_path='CAPTCHA.png'):\n  image = ImageCaptcha(width=500, height=100)\n  captcha_text = generate_captcha_text(captcha_length)\n  data = image.generate(captcha_text)\n  image.write(captcha_text, save_path)\n  return captcha_text\n\nif __name__ == '__main__':\n  captcha_text = generate_captcha()\n  print('CAPTCHA text:', captcha_text)\n\nImage.open('CAPTCHA.png')```\n\nПри желании можно добавить дополнительных эффектов и т.д., чтобы даже ChatGPT не справился\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_25@03-08-2024_21-19-31.jpg",
#       "width": 1209,
#       "height": 1280
#      }
#     }
#    }
#   },
#   {
#    "id": 62,
#    "content": {
#     "plain_text": "🎧🎸 Любишь музыку и хочешь создать что-то своё? Вот тебе репозиторий PyTorch WaveNet на GitHub — это как раз то, что нужно для экспериментов с аудио! \n\nЭтот проект основан на модели WaveNet, которая генерирует аудио с помощью глубокого обучения. Круто, правда? Можешь использовать этот инструмент для создания синтезированных звуков или даже музыки. Дай волю фантазии и проверь, на что способен WaveNet! Плюс ко всему, проект открытый, так что можешь дополнить его своими идеями. \n\nПочему бы не попробовать?\n\n📌 Github\n📌 Демо в Goggle Colab\n📌 Docs\n\n@pythonl",
#     "md_text": "🎧🎸 **Любишь музыку и хочешь создать что-то своё? Вот тебе репозиторий PyTorch WaveNet на GitHub — это как раз то, что нужно для экспериментов с аудио! **\n\nЭтот проект основан на модели WaveNet, которая генерирует аудио с помощью глубокого обучения. Круто, правда? Можешь использовать этот инструмент для создания синтезированных звуков или даже музыки. Дай волю фантазии и проверь, на что способен WaveNet! Плюс ко всему, проект открытый, так что можешь дополнить его своими идеями. \n\n**Почему бы не попробовать?**\n\n📌 [Github](https://github.com/vincentherrmann/pytorch-wavenet?tab=readme-ov-file#pytorch-wavenet)\n📌 [Демо в Goggle Colab](https://colab.research.google.com/github/vincentherrmann/pytorch-wavenet/blob/master/WaveNet_demo.ipynb)\n📌 [Docs](https://arxiv.org/abs/1609.03499)\n\n[@pythonl](https://t.me/pythonl)",
#     "image": {
#      "image": {
#       "file": "photos/photo_26@03-08-2024_21-20-11.jpg",
#       "width": 1280,
#       "height": 439
#      }
#     }
#    }
#   },
#   {
#    "id": 63,
#    "content": {
#     "plain_text": "🖥 Get Started with Python\n\nХороший курс по Python от Google. \n\nБолее 30 часов актуальных материалов, которые помогут вкатиться в тему.\n\nЗдесь разбирают основные концепции программирования на Python и другие фишки. Идеально, если давно хотели попробовать себя в IT.\n\n📌 Курс \n\n@pythonl",
#     "md_text": "🖥 **Get Started with Python**\n\nХороший курс по Python от Google. \n\n**Более 30 часов **актуальных материалов, которые помогут вкатиться в тему.\n\nЗдесь разбирают основные концепции программирования на Python и другие фишки. Идеально, если давно хотели попробовать себя в IT.\n\n📌 [Курс](https://www.classcentral.com/course/get-started-with-python-159166) \n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_27@03-08-2024_21-22-35.jpg",
#       "width": 604,
#       "height": 417
#      }
#     }
#    }
#   },
#   {
#    "id": 64,
#    "content": {
#     "plain_text": "🖥 Оптимизация  обработки Api запросов \n\nНесколько простых советов, которые помогут ускорить работу вашего REST API.\n\nhttps://fabridamicelli.github.io/posts/2023-07-13-optimize-fastapi.html\n\n@pythonl",
#     "md_text": "🖥 **Оптимизация  обработки Api запросов **\n\nНесколько простых советов, которые помогут ускорить работу вашего REST API.\n\nhttps://fabridamicelli.github.io/posts/2023-07-13-optimize-fastapi.html\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_28@03-08-2024_21-22-47.jpg",
#       "width": 1280,
#       "height": 1055
#      }
#     }
#    }
#   },
#   {
#    "id": 65,
#    "content": {
#     "plain_text": "⚡️ Google Recaptcha Solver\n\nИнструмент для решения Google reCAPTCHA.\n\nРазгадывает капчу менее чем за 5 секунд! 🚀\n\nЭто скрипт на Python для решения задачи Google reCAPTCHA с использованием библиотеки DrissionPage. \n\nsudo apt-get install ffmpeg\n\n • Github\n\n@pythonl",
#     "md_text": "⚡️ **Google Recaptcha Solver**\n\n*Инструмент для решения Google reCAPTCHA.*\n\nРазгадывает капчу менее чем за 5 секунд! 🚀\n\nЭто скрипт на Python для решения задачи Google reCAPTCHA с использованием библиотеки [DrissionPage](https://github.com/g1879/DrissionPage/tree/master). \n\nsudo apt-get install ffmpeg\n\n • [Github](https://github.com/sarperavci/GoogleRecaptchaBypass)\n\n@pythonl",
#     "video": {
#      "video": {
#       "file": "video_files/demo (1).mp4",
#       "media_type": "animation",
#       "duration_seconds": 10,
#       "width": 1920,
#       "height": 1080,
#       "file_name": "demo (1).mp4"
#      }
#     }
#    }
#   },
#   {
#    "id": 66,
#    "content": {
#     "plain_text": "Два репо в копилку\n\n🖥Первый - это справочник по Python, включает в себя разные темы:\nСинтаксис\nДанные\nБиблиотеки\n\nи тд.\n\n🖥Второй по React, для подготовки к собеседованию, включает в себя 100 вопросов из разных аспектов\n\nПодписаться\n\n#полезныересурсы",
#     "md_text": "**Два репо в копилку**\n\n🖥**Первый - это справочник по **[Python,](https://github.com/gto76/python-cheatsheet)** включает в себя разные темы:**\n```\nСинтаксис\nДанные\nБиблиотеки\n```\nи тд.\n\n🖥**Второй по **[React,](https://github.com/AndrewMosh/react_interview_cheatsheet?tab=readme-ov-file#%D1%87%D1%82%D0%BE-%D1%82%D0%B0%D0%BA%D0%BE%D0%B5-%D1%80%D0%B5%D0%B0%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D1%8B%D0%B9-%D0%BF%D0%BE%D1%82%D0%BE%D0%BA-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85-reactive-data-flow-%D0%B2-%D0%BA%D0%BE%D0%BD%D1%82%D0%B5%D0%BA%D1%81%D1%82%D0%B5-react)** для подготовки к собеседованию, включает в себя 100 вопросов из разных аспектов\n\n**> Подписаться**\n\n**#полезныересурсы",
#     "image": {
#      "image": {
#       "file": "photos/photo_29@06-08-2024_07-39-02.jpg",
#       "width": 896,
#       "height": 896
#      }
#     }
#    }
#   },
#   {
#    "id": 67,
#    "content": {
#     "plain_text": "📚 Infinite Bookshelf\n\nБесконечная книжная полка: Инструмент для создания полноценных книги за считанные секунды с помощью Grog и Llama3.\n\n▪️ Github: https://github.com/Bklieger/infinite-bookshelf\n▪️Live app: https://infinite.streamlit.app\n\n@pythonl",
#     "md_text": "📚 **Infinite Bookshelf\n**\nБесконечная книжная полка[:](http://t.me/pythonl) Инструмент для создания полноценных книги за считанные секунды с помощью Grog и Llama3.\n\n▪️ **Github**: https://github.com/Bklieger/infinite-bookshelf\n▪️**Live app**: https://infinite.streamlit.app\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_30@08-08-2024_07-32-17.jpg",
#       "width": 1280,
#       "height": 845
#      }
#     }
#    }
#   },
#   {
#    "id": 68,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_31@08-08-2024_07-32-17.jpg",
#       "width": 1280,
#       "height": 793
#      }
#     }
#    }
#   },
#   {
#    "id": 69,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "image": {
#      "image": {
#       "file": "photos/photo_32@08-08-2024_07-32-17.jpg",
#       "width": 1280,
#       "height": 1031
#      }
#     }
#    }
#   },
#   {
#    "id": 70,
#    "content": {
#     "plain_text": "💻Утренний мини-пост с книжкой для изучения SQL\n\nСодержит темы:\nОсновы реляционных БД;\nОсновы SQL;\nИспользование SQL для создания БД;\nХранение и извлечение данных:\nУправление операциями;\nРабота с XML-данными;\nSQL и JSON;\n\n\nЕсли есть что добавить, как обычно, велком ту комментс)\n\nПодписаться\n\n#книги",
#     "md_text": "💻**Утренний мини-пост с книжкой для изучения SQL**\n\nСодержит темы:\n> Основы реляционных БД;\nОсновы SQL;\nИспользование SQL для создания БД;\nХранение и извлечение данных:\nУправление операциями;\nРабота с XML-данными;\nSQL и JSON;\n**\n**\nЕсли есть что добавить, как обычно, велком ту комментс)\n\n> Подписаться**\n\n**#книги",
#     "file": {
#      "file": {
#       "file_name": "SQL для чайников.pdf",
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "mime_type": "application/pdf"
#      }
#     }
#    }
#   },
#   {
#    "id": 71,
#    "content": {
#     "plain_text": "Whoogle search — получайте результаты поиска Google, но без рекламы, javascript, AMP-ссылок, cookies и отслеживания IP-адресов. \n\nЛегко разворачивается в один клик как приложение Docker и настраивается с помощью одного файла конфигурации.\n\n⛓ Ознакомиться: GitHub\n\n👉 @BackendPortal | #ресурсы",
#     "md_text": "**Whoogle search **— получайте результаты поиска Google, но без рекламы, javascript, AMP-ссылок, cookies и отслеживания IP-адресов. \n\nЛегко разворачивается в один клик как приложение Docker и настраивается с помощью одного файла конфигурации.\n\n⛓ Ознакомиться: [GitHub](https://github.com/benbusby/whoogle-search)\n\n👉 @BackendPortal | #ресурсы",
#     "image": {
#      "image": {
#       "file": "photos/photo_33@12-08-2024_09-56-59.jpg",
#       "width": 1280,
#       "height": 719
#      }
#     }
#    }
#   },
#   {
#    "id": 72,
#    "content": {
#     "plain_text": "Вёрстка сайта с нуля до результата, используя современные технологии - SCSS, html, БЭМ\n\nВ данном видео вы создадите сайт на HTML и SCSS с нуля. Также там объяснят методологию БЭМ простым языком и покажут на реальном примере, как делается адаптивная верстка сайта\n\n📹 Cмотреть видео: YouTube\n\n➡️ @FrontendPortal | #видео",
#     "md_text": "**Вёрстка сайта с нуля до результата, используя современные технологии - SCSS, html, БЭМ**\n\nВ данном видео вы создадите сайт на HTML и SCSS с нуля. Также там объяснят методологию БЭМ простым языком и покажут на реальном примере, как делается адаптивная верстка сайта\n\n📹 **Cмотреть видео:** [YouTube](https://youtu.be/fFKBm9cDYgk?si=KdS50ztR1Bv2EiLq)\n\n➡️ @FrontendPortal | #видео",
#     "image": {
#      "image": {
#       "file": "photos/photo_34@14-08-2024_09-17-40.jpg",
#       "width": 1280,
#       "height": 720
#      }
#     }
#    }
#   },
#   {
#    "id": 74,
#    "content": {
#     "plain_text": "Torrent Hunt Bot – исходный код лучшего бота для поиска торрентов в Telegram. \n\nМожет говорить на 19 разных языках, включая русский.\n\n⛓ Ознакомиться: GitHub\n\n👉 @BackendPortal | #ресурсы",
#     "md_text": "**Torrent Hunt Bot **– исходный код лучшего бота для поиска торрентов в Telegram. \n\nМожет говорить на 19 разных языках, включая русский.\n\n⛓ Ознакомиться: [GitHub](https://github.com/hemantapkh/TorrentHunt)\n\n👉 @BackendPortal | #ресурсы",
#     "image": {
#      "image": {
#       "file": "photos/photo_35@14-08-2024_09-22-25.jpg",
#       "width": 1280,
#       "height": 719
#      }
#     }
#    }
#   },
#   {
#    "id": 75,
#    "content": {
#     "plain_text": "Расширенный курс введение в DevOps\n\nКурс включает основы DevOps, работу в терминале, сети, CI/CD, IaC, Kubernetes, облака, инфраструктуру, мониторинг, базы данных, Vagrant и итоговый проект\n\n📹 Cмотреть курс: YouTube\n\n 👉 @BackendPortal | #курсы",
#     "md_text": "**Расширенный курс введение в DevOps**\n\nКурс включает основы DevOps, работу в терминале, сети, CI/CD, IaC, Kubernetes, облака, инфраструктуру, мониторинг, базы данных, Vagrant и итоговый проект\n\n📹 **Cмотреть курс:** [YouTube](https://youtube.com/playlist?list=PLQoP6S9f51EZM0-WqAWAAkwAB28gnWkTb&si=PMPrbP8QEM096pec)\n\n 👉 @BackendPortal | #курсы",
#     "image": {
#      "image": {
#       "file": "photos/photo_36@14-08-2024_09-22-39.jpg",
#       "width": 1280,
#       "height": 676
#      }
#     }
#    }
#   },
#   {
#    "id": 76,
#    "content": {
#     "plain_text": "vimGPT — интересный проект голосового помощника на базе GPT-4V, который может самостоятельно взаимодействовать с интернетом и браузером в частности.\n\nДжарвис умеет заполнять формы, регистрироваться на сайтах, серфить интернет и даже совершать онлайн покупки.\n\n⛓ Ознакомиться: GitHub\n\n👉 @BackendPortal | #ресурсы",
#     "md_text": "**vimGPT** — интересный проект голосового помощника на базе GPT-4V, который может самостоятельно взаимодействовать с интернетом и браузером в частности.\n\nДжарвис умеет заполнять формы, регистрироваться на сайтах, серфить интернет и даже совершать онлайн покупки.\n\n⛓ Ознакомиться: [GitHub](https://github.com/ishan0102/vimGPT)\n\n👉 @BackendPortal | #ресурсы",
#     "video": {
#      "video": {
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "media_type": "video_file",
#       "duration_seconds": 36,
#       "width": 1884,
#       "height": 924,
#       "file_name": "@python2day.mp4"
#      }
#     }
#    }
#   },
#   {
#    "id": 77,
#    "content": {
#     "plain_text": "ScrapeGraphAI – это библиотека Python для парсинга веб-страниц с помощью искусственного интеллекта.\n\nПредоставляет подробную документацию и примеры использования для различных случаев.\n\n⛓ Ознакомиться: GitHub\n\n👉 @BackendPortal | #ресурсы",
#     "md_text": "**ScrapeGraphAI** – это библиотека Python для парсинга веб-страниц с помощью искусственного интеллекта.\n\nПредоставляет подробную документацию и примеры использования для различных случаев.\n\n⛓ Ознакомиться: [GitHub](https://github.com/VinciGit00/Scrapegraph-ai)\n\n👉 @BackendPortal | #ресурсы",
#     "image": {
#      "image": {
#       "file": "photos/photo_37@14-08-2024_09-25-51.jpg",
#       "width": 1280,
#       "height": 719
#      }
#     }
#    }
#   },
#   {
#    "id": 78,
#    "content": {
#     "plain_text": "Вся база SQL для начинающих\n\n🕔 Длительность: 1ч. 19м\n\nВы узнаете всё, что нужно знать про основы SQL\n\n📹 Cмотреть курс: YouTube\n\n 👉 @BackendPortal | #курсы #SQL",
#     "md_text": "**Вся база SQL для начинающих**\n\n🕔 Длительность: 1ч. 19м\n\nВы узнаете всё, что нужно знать про основы SQL\n\n📹 **Cмотреть курс:** [YouTube](https://youtu.be/5sG9kmXYsKU?si=vF1g7SFLEgfEWygl)\n\n 👉 @BackendPortal | #курсы #SQL",
#     "image": {
#      "image": {
#       "file": "photos/photo_38@14-08-2024_09-26-01.jpg",
#       "width": 1280,
#       "height": 720
#      }
#     }
#    }
#   },
#   {
#    "id": 79,
#    "content": {
#     "plain_text": "Node JS фундаментальный курс от А до Я. Node.js Теория и практика\n\n🕔 Длительность: 2ч.\n\nВ этом курсе вы разберете основные теоретические и практические моменты связанные с node js. Сделаете небольшой фреймворк на node js. Научитесь работать с базами данных. В конце вас ждет план на дальнейшее обучение\n\n📹 Cмотреть курс: YouTube\n\n 👉 @BackendPortal | #курсы #NodeJs",
#     "md_text": "**Node JS фундаментальный курс от А до Я. Node.js Теория и практика**\n\n🕔 Длительность: 2ч.\n\nВ этом курсе вы разберете основные теоретические и практические моменты связанные с node js. Сделаете небольшой фреймворк на node js. Научитесь работать с базами данных. В конце вас ждет план на дальнейшее обучение\n\n📹 **Cмотреть курс:** [YouTube](https://youtu.be/243pQXC5Ebs?si=s347aLLxWsta5ekz)\n\n 👉 @BackendPortal | #курсы #NodeJs",
#     "image": {
#      "image": {
#       "file": "photos/photo_39@14-08-2024_09-26-22.jpg",
#       "width": 1280,
#       "height": 720
#      }
#     }
#    }
#   },
#   {
#    "id": 80,
#    "content": {
#     "plain_text": "Awesome Backend — структурированный список ресурсов(на английском и русском языке) для изучения Backend разработки, который поможет систематизировать свои знания и составить план обучения\n\n⛓ Ознакомиться: Тык\n\n👉 @BackendPortal | #ресурсы",
#     "md_text": "**Awesome Backend** — структурированный список ресурсов(на английском и русском языке) для изучения Backend разработки, который поможет систематизировать свои знания и составить план обучения\n\n⛓ Ознакомиться: [Тык](https://github.com/zhashkevych/awesome-backend)\n\n👉 @BackendPortal | #ресурсы",
#     "image": {
#      "image": {
#       "file": "photos/photo_40@14-08-2024_09-26-32.jpg",
#       "width": 1280,
#       "height": 719
#      }
#     }
#    }
#   },
#   {
#    "id": 81,
#    "content": {
#     "plain_text": "backend-cheats — Этот репозиторий представляет собой визуальную шпаргалку по основным темам Backend-разработки. Весь материал разделен на главы, включающие различные темы\n\nКаждая тема состоит из трех основных частей:\n— Различные изображения/таблицы/шпаргалки для лучшего понимания\n— Краткое резюме со списком ключевых терминов и понятий\n— Ресурсы, на которых можно найти полную информацию по тому или иному вопросу\n\n⛓ Ознакомиться: Тык\n\n👉 @BackendPortal | #ресурсы",
#     "md_text": "**backend-cheats** — Этот репозиторий представляет собой визуальную шпаргалку по основным темам Backend-разработки. Весь материал разделен на главы, включающие различные темы\n\nКаждая тема состоит из трех основных частей:\n— Различные изображения/таблицы/шпаргалки для лучшего понимания\n— Краткое резюме со списком ключевых терминов и понятий\n— Ресурсы, на которых можно найти полную информацию по тому или иному вопросу\n\n⛓ Ознакомиться: [Тык](https://github.com/cheatsnake/backend-cheats)\n\n👉 @BackendPortal | #ресурсы",
#     "image": {
#      "image": {
#       "file": "photos/photo_41@14-08-2024_09-27-00.jpg",
#       "width": 1280,
#       "height": 719
#      }
#     }
#    }
#   },
#   {
#    "id": 82,
#    "content": {
#     "plain_text": "🖥 The Algorithms - Python\n\nОтличная подборка самых популярных алгоритмов на Python.\n\nИдеально подходит для обучения, хотя реализации могут быть менее эффективными по сравнению с теми, что есть в стандартной библиотеке Python (но это не точно).\n\n▪GitHub \n▪веб-сайт\n\n@pythonl",
#     "md_text": "🖥 **The Algorithms - Python**\n\nОтличная подборка самых популярных алгоритмов на Python.\n\nИдеально подходит для обучения, хотя реализации могут быть менее эффективными по сравнению с теми, что есть в стандартной библиотеке Python (но это не точно).\n\n▪[GitHub](https://github.com/TheAlgorithms/Python) \n▪[веб-сайт](https://the-algorithms.com/ru)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_42@17-08-2024_13-02-38.jpg",
#       "width": 1280,
#       "height": 683
#      }
#     }
#    }
#   },
#   {
#    "id": 83,
#    "content": {
#     "plain_text": "🖥 Преобразование Pdf в аудио с помощью Python\n\n@pythonl",
#     "md_text": "🖥 **Преобразование Pdf в аудио с помощью Python**\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_43@17-08-2024_13-04-22.jpg",
#       "width": 1146,
#       "height": 1270
#      }
#     }
#    }
#   },
#   {
#    "id": 84,
#    "content": {
#     "plain_text": "🖥 Nala\n\nЭто интерфейс для libapt-pkg, работающий с python-apt API. \n\nНачинающим пользователям часто бывает непросто разобраться, что именно делает apt при установке или обновлении пакетов. \n\nNala решает эту проблему, убирая лишние сообщения, улучшая форматирование и используя цветовую индикацию, чтобы наглядно показать, что произойдет с пакетом при установке, удалении или обновлении.\n\n ▪ Github\n\n@pythonl",
# ...
#     "image": {
#      "image": {
#       "file": "photos/photo_124@03-12-2024_23-45-06.jpg",
#       "width": 358,
#       "height": 763
#      }
#     }
#    }
#   },
#   {
#    "id": 261,
#    "content": {
#     "plain_text": "🖥 Python-hdwallet \n\nЭто библиотека на Python, предназначенная для создания и работы с иерархическими детерминированными кошельками (HD Wallet), поддерживающими свыше 200 различных криптовалют.\n\nHD Wallets – это аббревиатура от Hierarchical Deterministic Wallets (иерархический детерминированный кошелек). Являясь кошельком криптовалют нового поколения он способен генерировать любое количества ключей на основе главного открытого ключа.\n\nБиблиотека предоставляет возможность генерации миллионов адресов и управления ключами, а также включает функции для безопасного создания сид-фраз и удобного взаимодействия с блокчейнами.\n\npip install hdwallet\n\n🖥 GitHub\n\n@pythonl",
#     "md_text": "🖥 **Python-hdwallet** \n\nЭто библиотека на **Python**, предназначенная для создания и работы с иерархическими **детерминированными кошельками (**HD Wallet), поддерживающими свыше 200 различных криптовалют.\n\n**HD Wallet**s – это аббревиатура от Hierarchical Deterministic Wallets (иерархический детерминированный кошелек). Являясь кошельком криптовалют нового поколения он способен генерировать любое количества ключей на основе главного открытого ключа.\n\nБиблиотека предоставляет возможность генерации миллионов адресов и управления ключами, а также включает функции для безопасного создания сид-фраз и удобного взаимодействия с блокчейнами.\n\npip install hdwallet\n\n🖥 [GitHub](https://github.com/talonlab/python-hdwallet)\n\n@pythonl",
#     "image": {
#      "image": {
#       "file": "photos/photo_125@03-12-2024_23-45-50.jpg",
#       "width": 1280,
#       "height": 573
#      }
#     }
#    }
#   },
#   {
#    "id": 262,
#    "content": {
#     "plain_text": "SmolChat-Android\n\nSmolChat — это Android приложение, которое предназначено для работы с малыми языковыми моделями на устройствах Android, позволяя пользователям добавлять и удалять модели, а также настраивать параметры системы через удобный интерфейс. \n\nВ дальнейшем разработчики планируют расширить функционал приложения, добавив поддержку не-ASCII ответов, автоматическое именование чатов, функцию поиска сообщений, интеграцию с десктопными приложениями и оптимизацию производительности и генерации ответов. \n\nhttps://github.com/shubham0204/SmolChat-Android\n================\n👁 @open_source_friend",
#     "md_text": "**SmolChat-Android**\n\nSmolChat — это Android приложение, которое предназначено для работы с малыми языковыми моделями на устройствах Android[,](https://t.me/black_triangle_tg) позволяя пользователям добавлять и удалять модели[,](https://t.me/black_triangle_tg) а также настраивать параметры системы через удобный интерфейс[.](https://t.me/black_triangle_tg) \n\nВ дальнейшем разработчики планируют расширить функционал приложения[,](https://t.me/black_triangle_tg) добавив поддержку не-ASCII ответов[,](https://t.me/black_triangle_tg) автоматическое именование чатов[,](https://t.me/black_triangle_tg) функцию поиска сообщений[,](https://t.me/black_triangle_tg) интеграцию с десктопными приложениями и оптимизацию производительности и генерации ответов[.](https://t.me/black_triangle_tg) \n\nhttps://github.com/shubham0204/SmolChat-Android\n================\n👁** **@open_source_friend",
#     "video": {
#      "video": {
#       "file": "video_files/1 (45).mp4",
#       "media_type": "video_file",
#       "duration_seconds": 12,
#       "width": 720,
#       "height": 720,
#       "file_name": "1.mp4"
#      }
#     }
#    }
#   },
#   {
#    "id": 263,
#    "content": {
#     "plain_text": "Полное руководство по GitHub Actions [2023]\n\n🚩Курс \"Полное руководство по GitHub Actions\" представляет собой обширное обучающее программу, которая призвана помочь участникам освоить инструмент автоматизации рабочего процесса GitHub Actions.\n\n✏️В ходе курса участники научатся создавать и настраивать рабочие процессы, используя предоставляемые инструменты и функции GitHub Actions. Они изучат различные сценарии использования, такие как автоматическое тестирование кода, непрерывная интеграция и развертывание приложений.\n\nНачал изучать программирование из любопытства и не мог остановиться... Теперь я главный программист!\n\nСКАЧАТЬ",
#     "md_text": "**Полное руководство по GitHub Actions [2023]**\n\n🚩Курс \"Полное руководство по GitHub Actions\" представляет собой обширное обучающее программу, которая призвана помочь участникам освоить инструмент автоматизации рабочего процесса GitHub Actions.\n\n✏️В ходе курса участники научатся создавать и настраивать рабочие процессы, используя предоставляемые инструменты и функции GitHub Actions. Они изучат различные сценарии использования, такие как автоматическое тестирование кода, непрерывная интеграция и развертывание приложений.\n\n**Начал изучать программирование из любопытства и не мог остановиться... Теперь я главный программист!**\n\n[СКАЧАТЬ](https://t.me/bakender/721)",
#     "image": {
#      "image": {
#       "file": "photos/photo_126@05-12-2024_08-23-13.jpg",
#       "width": 1280,
#       "height": 827
#      }
#     }
#    }
#   },
#   {
#    "id": 264,
#    "content": {
#     "plain_text": "Курс по сетевому хранилищу с TrueNAS - FreeNAS (2022)\n\n✉️На практических примерах научимся устанавливать и настраивать TrueNAS. Создадим и подключим RAID-массивы, настроим репликацию и будем следить за состоянием жестких дисков. Научимся работать с пулами и кластерами. Запускаем систему отчетности и логирования. Настроим права доступа и безопасность, а также научимся работать с такой классной штукой, как iSCSI.\n\nС каждым новым проектом я расширяю свои знания и навыки!\n\nСКАЧАТЬ",
#     "md_text": "**Курс по сетевому хранилищу с TrueNAS - FreeNAS (2022)**\n\n✉️На практических примерах научимся устанавливать и настраивать TrueNAS. Создадим и подключим RAID-массивы, настроим репликацию и будем следить за состоянием жестких дисков. Научимся работать с пулами и кластерами. Запускаем систему отчетности и логирования. Настроим права доступа и безопасность, а также научимся работать с такой классной штукой, как iSCSI.\n\n**С каждым новым проектом я расширяю свои знания и навыки!**\n\n[СКАЧАТЬ](https://t.me/bakender/722)",
#     "image": {
#      "image": {
#       "file": "photos/photo_127@05-12-2024_09-02-44.jpg",
#       "width": 1280,
#       "height": 827
#      }
#     }
#    }
#   },
#   {
#    "id": 265,
#    "content": {
#     "plain_text": "Курс по Rust\n\n⭐️Курс по языку программирования Rust предназначен для тех, кто хочет изучить все преимущества этого языка. \n\n🥸Для начала обучения вам не нужны знания программирования, так как материал очень хорошо преподнесен и у вас не возникнет сложностей с освоением.\n\nМои проекты по программированию стали неотъемлемой частью моей жизни!\n\nСКАЧАТЬ",
#     "md_text": "**Курс по Rust**\n\n⭐️Курс по языку программирования Rust предназначен для тех, кто хочет изучить все преимущества этого языка. \n\n🥸Для начала обучения вам не нужны знания программирования, так как материал очень хорошо преподнесен и у вас не возникнет сложностей с освоением.\n\n**Мои проекты по программированию стали неотъемлемой частью моей жизни!**\n\n[СКАЧАТЬ](https://cloud.mail.ru/public/knSr/bYuDYnU33)",
#     "image": {
#      "image": {
#       "file": "photos/photo_128@05-12-2024_09-02-55.jpg",
#       "width": 1280,
#       "height": 827
#      }
#     }
#    }
#   },
#   {
#    "id": 266,
#    "content": {
#     "plain_text": "Практический курс по Big Data (2023) [RU]\n\n🔐Курс \"Практический курс по Big Data\" предназначен для тех, кто хочет изучить основы анализа больших данных и применить их на практике. В ходе обучения студенты узнают о технологиях и инструментах, используемых для обработки и анализа больших объемов данных, таких как Hadoop, Spark, SQL, NoSQL и другие.\n\nМир программирования так богат и разнообразен, что я всегда нахожу что-то новое для себя!\n\nСКАЧАТЬ",
#     "md_text": "**Практический курс по Big Data (2023) [RU]**\n\n🔐Курс \"Практический курс по Big Data\" предназначен для тех, кто хочет изучить основы анализа больших данных и применить их на практике. В ходе обучения студенты узнают о технологиях и инструментах, используемых для обработки и анализа больших объемов данных, таких как Hadoop, Spark, SQL, NoSQL и другие.\n\n**Мир программирования так богат и разнообразен, что я всегда нахожу что-то новое для себя!**\n\n[СКАЧАТЬ](https://t.me/bakender/724)",
#     "image": {
#      "image": {
#       "file": "photos/photo_129@05-12-2024_09-03-11.jpg",
#       "width": 1280,
#       "height": 827
#      }
#     }
#    }
#   },
#   {
#    "id": 267,
#    "content": {
#     "plain_text": "Git - Курс по Git и GitHub (2023)\n\n📌Этот курс посвящен основным функциям Git и GitHub. Узнайте, как использовать Git и GitHub: - Коммиты, ветки, слияние, GitHub и Git Objects. Если эти термины для вас новые — становитесь студентом этого курса и вы узнаете, что такое Git и как использовать его основные функции. Ознакомьтесь с Git и GitHub, чтобы использовать их в своих проектах и проектах, в которых вы потенциально будете участвовать в будущем.\n\nБлагодаря этому курсу я не просто стал программистом – я стал частью удивительного мира технологий!\n\nСКАЧАТЬ",
#     "md_text": "**Git - Курс по Git и GitHub (2023)**\n\n📌Этот курс посвящен основным функциям Git и GitHub. Узнайте, как использовать Git и GitHub: - Коммиты, ветки, слияние, GitHub и Git Objects. Если эти термины для вас новые — становитесь студентом этого курса и вы узнаете, что такое Git и как использовать его основные функции. Ознакомьтесь с Git и GitHub, чтобы использовать их в своих проектах и проектах, в которых вы потенциально будете участвовать в будущем.\n**\nБлагодаря этому курсу я не просто стал программистом – я стал частью удивительного мира технологий!**\n\n[СКАЧАТЬ](https://t.me/bakender/729)",
#     "image": {
#      "image": {
#       "file": "photos/photo_130@05-12-2024_09-03-34.jpg",
#       "width": 1280,
#       "height": 827
#      }
#     }
#    }
#   },
#   {
#    "id": 268,
#    "content": {
#     "plain_text": "Многозадачность в Python. Многопроцессное программирование\n\n📌Курс полностью раскрывает тему процессной многозадачности.\n\n🗓Курс является второй частью большой темы реализации многозадачных решений в python и полностью раскрывает процессную многозадачность.\n\nНаучившись программировать, я почувствовал себя архитектором своего будущего!\n\nСКАЧАТЬ",
#     "md_text": "**Многозадачность в Python. Многопроцессное программирование**\n\n📌Курс полностью раскрывает тему процессной многозадачности.\n\n🗓Курс является второй частью большой темы реализации многозадачных решений в python и полностью раскрывает процессную многозадачность.\n\n**Научившись программировать, я почувствовал себя архитектором своего будущего!**\n\n[СКАЧАТЬ](https://t.me/bakender/747)",
#     "image": {
#      "image": {
#       "file": "photos/photo_131@05-12-2024_09-04-14.jpg",
#       "width": 1280,
#       "height": 827
#      }
#     }
#    }
#   },
#   {
#    "id": 269,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "file": {
#      "file": {
#       "file_name": "Полное руководство по GitHub Actions.zip",
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "mime_type": "application/zip"
#      }
#     }
#    }
#   },
#   {
#    "id": 270,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "file": {
#      "file": {
#       "file_name": "Udemy_Курс_по_сетевому_хранилищу_с_TrueNAS_FreeNAS_2022.zip",
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "mime_type": "application/zip"
#      }
#     }
#    }
#   },
#   {
#    "id": 271,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "file": {
#      "file": {
#       "file_name": "Практический курс по Big Data.zip",
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "mime_type": "application/zip"
#      }
#     }
#    }
#   },
#   {
#    "id": 272,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "file": {
#      "file": {
#       "file_name": "part 1.zip",
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "mime_type": "application/zip"
#      }
#     }
#    }
#   },
#   {
#    "id": 273,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "file": {
#      "file": {
#       "file_name": "part 2.zip",
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "mime_type": "application/zip"
#      }
#     }
#    }
#   },
#   {
#    "id": 274,
#    "content": {
#     "plain_text": "",
#     "md_text": "",
#     "file": {
#      "file": {
#       "file_name": "Многозадачность_в_Python_Многопроцессное_программирование.7z",
#       "file": "(File exceeds maximum size. Change data exporting settings to download.)",
#       "mime_type": "application/x-7z-compressed"
#      }
#     }
#    }
#   },
#   {
#    "id": 275,
#    "content": {
#     "plain_text": "🖥 Textual\n\nСоздание интерактивных пользовательских интерфейсов в терминале с графиками и виджетами требует знаний инизкоуровневого программирования. \n\nЧтобы создать сложный CLI, используя простого Python API, попробуйте Textual.\n\n🖥 Github\n\n@pythonl",
#     "md_text": "🖥 **Textual**\n\nСоздание интерактивных пользовательских интерфейсов в терминале с графиками и виджетами требует знаний инизкоуровневого программирования. \n\nЧтобы создать сложный CLI, используя простого Python API, попробуйте [Textual](http://github.com/Textualize/textual).\n\n🖥 [Github](http://github.com/Textualize/textual)\n\n@pythonl",
#     "video": {
#      "video": {
#       "file": "video_files/ssstwitter.com_1733415870523.mp4",
#       "media_type": "video_file",
#       "duration_seconds": 8,
#       "width": 960,
#       "height": 520,
#       "file_name": "ssstwitter.com_1733415870523.mp4"
#      }
#     }
#    }
#   },
#   {
#    "id": 276,
#    "content": {
#     "plain_text": "rec-all\n\nrec-all — это программа, которая помогает пользователям управлять своими цифровыми воспоминаниями. \n\nПриложение, функционирующее как \"машина времени\", производит автоматическую запись экрана и распознавание текста, а затем  использует искусственный интеллект для организации и индексации этих данных.\n\nRec-all разрабатывается на основе открытого исходного кода, обеспечивая конфиденциальность, за счет локальной обработки данных.\n\nhttps://github.com/bruuno-studio/rec-all\n================\n👁 @open_source_friend",
#     "md_text": "**rec-all**\n\nrec-all — это программа[,](https://t.me/open_source_friend) которая помогает пользователям управлять своими цифровыми воспоминаниями[.](https://t.me/open_source_friend) \n\nПриложение[,](https://t.me/open_source_friend) функционирующее как \"машина времени\"[,](https://t.me/open_source_friend) производит автоматическую запись экрана и распознавание текста[,](https://t.me/open_source_friend) а затем  использует искусственный интеллект для организации и индексации этих данных[.](https://t.me/open_source_friend)\n\nRec-all разрабатывается на основе открытого исходного кода[,](https://t.me/open_source_friend) обеспечивая конфиденциальность[,](https://t.me/open_source_friend) за счет локальной обработки данных[.](https://t.me/open_source_friend)\n\nhttps://github.com/bruuno-studio/rec-all\n================\n👁** **@open_source_friend",
#     "video": {
#      "video": {
#       "file": "video_files/1 (46).mp4",
#       "media_type": "video_file",
#       "duration_seconds": 60,
#       "width": 464,
#       "height": 320,
#       "file_name": "1.mp4"
#      }
#     }
#    }
#   },
#   {
#    "id": 277,
#    "content": {
#     "plain_text": "Проверка всевозможных text_entities\n\nЖирный текст\nИталик\nПодчеркнутый\nЗачеркнутый\nЦитата\nМоноширинный\nскрытый",
#     "md_text": "Проверка всевозможных text_entities\n\n**Жирный текст**\n*Италик*\n__Подчеркнутый__\n~~Зачеркнутый~~\n> Цитата\n```\nМоноширинный```\n||скрытый||"
#    }
#   }
#  ]
# }
